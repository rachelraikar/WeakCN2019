# %% [markdown]
# # Automation Version 4.3
#
# Work on S-type stellar spectra by Rachel Raikar and Antara Bhattacharya.

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
img = fits.getdata('../FORSOPHIE/Jan5/BBTau_90sec.fits', ignore_missing_end=True)
header = fits.getheader('../FORSOPHIE/Jan5/BBTau_90sec.fits', 0)
#print(header)
hdu1 = fits.open('../FORSOPHIE/Jan5/BBTau_90sec.fits')
hdu1[0].header['FIXPIX']
    
plt.figure()
plt.imshow(img)
plt.show()

# %%
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 1651 / Axis length
# NAXIS2  =                  107 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2018-01-18T19:43:42' / Date FITS file was generated
# IRAF-TLM= '2018-01-18T19:43:46' / Time of last modification
# OBSERVAT= 'APO'                / Per the IRAF observatory list.
# TELESCOP= '3.5m'
# INSTRUME= 'echelle'            / Instrument name
# LATITUDE= +3.2780361000000E+01 / Latitude of telescope base
# LONGITUD= -1.0582041700000E+02 / Longitude of telescope base
# TIMESYS = 'TAI'                / Time system for DATE-OBS
# UTC-TAI = -37.0                / UTC = TAI + UTC_TAI(seconds)
# UT1-TAI = -36.79               / UT1 = TAI + UT1_TAI(seconds)
# ...

# %%
print(hdu1)
hdu1
type(hdu1)
# Out:
# ...
# astropy.io.fits.hdu.hdulist.HDUList

# %%
hdu1.info()
# Out:
# Filename: ../FORSOPHIE/Jan5/BBTau_90sec.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     359   (1651, 107)   float32

# %%
from aesop import EchelleSpectrum as es
spectrum = es.from_fits('../FORSOPHIE/Jan5/BBTau_90sec.fits')
print(spectrum)
spec = spectrum[86]
spec2 = spectrum[87]
spec3 = spectrum[88]
spec4 = spectrum[89]
spec5 = spectrum[90]
spec6 = spectrum[91]
spec.plot(color="steelblue")
spec2.plot(color = "steelblue")
spec3.plot(color="steelblue")
spec4.plot(color="steelblue")
spec5.plot(color = "steelblue")
spec6.plot(color="steelblue")
# Out:
# <EchelleSpectrum: 107 orders, 3506.1-10611.1 Angstrom>

# %%
spec = spectrum[10]
spec2 = spectrum[45]
spec3 = spectrum[70]
spec4 = spectrum[95]
spec.plot()
spec2.plot()
spec3.plot()
spec4.plot()

# %%
# specx = spectrum[89]
# s2 = es.continuum_normalize_from_standard(, polynomial_order=8)
# s2.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-f1c295a13eb7> in <module>
#       1 specx = spectrum[89]
# ----> 2 s2 = es.continuum_normalize_from_standard(standard_spectrum, polynomial_order=8)
#       3 s2.plot()
#
# NameError: name 'standard_spectrum' is not defined

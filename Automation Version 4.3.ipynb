# %% [markdown]
# # Automation Version 4.3
#
# Work on S-type stellar spectra by Rachel Raikar and Antara Bhattacharya.

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
img = fits.getdata('../FORSOPHIE/RGEm.0029.wfrmcpc.fits', ignore_missing_end=True)
header = fits.getheader('../FORSOPHIE/RGEm.0029.wfrmcpc.fits', 0)
#print(header)
hdu1 = fits.open('../FORSOPHIE/RGEm.0029.wfrmcpc.fits')
#hdu1[0].header['CDELT']
    
plt.figure()
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-185f9eb2ff93> in <module>
#       5 #print(header)
#       6 hdu1 = fits.open('../FORSOPHIE/RGEm.0029.wfrmcpc.fits')
# ----> 7 hdu1[0].header['CDELT']
#       8
#       9 plt.figure()
#
# ~\Anaconda3\lib\site-packages\astropy\io\fits\header.py in __getitem__(self, key)
#     143         else:
#     144             keyword = key
# --> 145         card = self._cards[self._cardindex(key)]
#     146         if card.field_specifier is not None and keyword == card.rawkeyword:
#     147             # This is RVKC; if only the top-level keyword was specified return
#
# ~\Anaconda3\lib\site-packages\astropy\io\fits\header.py in _cardindex(self, key)
#    1652
#    1653         if not indices:
# -> 1654             raise KeyError("Keyword {!r} not found.".format(keyword))
#    1655
#    1656         try:
#
# ...

# %%
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 1651 / Axis length
# NAXIS2  =                  107 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2018-01-02T22:12:36' / Date FITS file was generated
# IRAF-TLM= '2018-01-02T22:12:40' / Time of last modification
# OBSERVAT= 'APO'                / Per the IRAF observatory list.
# TELESCOP= '3.5m'
# INSTRUME= 'echelle'            / Instrument name
# LATITUDE= +3.2780361000000E+01 / Latitude of telescope base
# LONGITUD= -1.0582041700000E+02 / Longitude of telescope base
# TIMESYS = 'TAI'                / Time system for DATE-OBS
# UTC-TAI = -37.0                / UTC = TAI + UTC_TAI(seconds)
# UT1-TAI = -36.78               / UT1 = TAI + UT1_TAI(seconds)
# ...
